# %%
import sys, mlflow, sklearn, deepchecks
print(sys.executable)
print("mlflow", mlflow.__version__, "| sklearn", sklearn.__version__)
# Out:
# /home/jhonatan0925/mlops/tc5044-mlops/.venv/lib/python3.11/site-packages/deepchecks/core/serialization/dataframe/html.py:16: UserWarning:
#
# pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# /home/jhonatan0925/mlops/tc5044-mlops/.venv/bin/python
# mlflow 3.16.1 | sklearn 1.7.2
